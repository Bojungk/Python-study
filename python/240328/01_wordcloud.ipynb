# %%
# !pip install wordcloud
# !pip install konlpy
# Out:
# Requirement already satisfied: wordcloud in c:\파이썬이다\lib\site-packages (1.9.3)
# Requirement already satisfied: numpy>=1.6.1 in c:\파이썬이다\lib\site-packages (from wordcloud) (1.26.4)
# Requirement already satisfied: pillow in c:\파이썬이다\lib\site-packages (from wordcloud) (10.2.0)
# Requirement already satisfied: matplotlib in c:\파이썬이다\lib\site-packages (from wordcloud) (3.8.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\파이썬이다\lib\site-packages (from matplotlib->wordcloud) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\파이썬이다\lib\site-packages (from matplotlib->wordcloud) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\파이썬이다\lib\site-packages (from matplotlib->wordcloud) (4.50.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\파이썬이다\lib\site-packages (from matplotlib->wordcloud) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\qhwjd\appdata\roaming\python\python312\site-packages (from matplotlib->wordcloud) (24.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\파이썬이다\lib\site-packages (from matplotlib->wordcloud) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\qhwjd\appdata\roaming\python\python312\site-packages (from matplotlib->wordcloud) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\qhwjd\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: konlpy in c:\파이썬이다\lib\site-packages (0.6.0)
# Requirement already satisfied: JPype1>=0.7.0 in c:\파이썬이다\lib\site-packages (from konlpy) (1.5.0)
# Requirement already satisfied: lxml>=4.1.0 in c:\파이썬이다\lib\site-packages (from konlpy) (5.1.0)
# Requirement already satisfied: numpy>=1.6 in c:\파이썬이다\lib\site-packages (from konlpy) (1.26.4)
# Requirement already satisfied: packaging in c:\users\qhwjd\appdata\roaming\python\python312\site-packages (from JPype1>=0.7.0->konlpy) (24.0)
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from wordcloud import WordCloud
from konlpy.tag import Okt
from collections import Counter
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image

# %%
#txt 파일을 로드
text= open("hiphop.txt", encoding="euc-kr").read()

# %%
text
# Out:
# '"보고 싶다\n이렇게 말하니까 더 보고 싶다\n너희 사진을 보고 있어도\n보고 싶다\n너무 야속한 시간\n나는 우리가 밉다\n이젠 얼굴 한번 보는 것 조차\n힘들어진 우리가\n여긴 온통 겨울 뿐이야\n8월에도 겨울이 와\n마음은 시간을 달려가네\n홀로 남은 설국열차\n니 손 잡고 지구 반대편까지 가\n겨울을 끝내고파\n그리움들이 얼마나\n눈처럼 내려야 그 봄날이 올까\nFriend\n허공을 떠도는\n작은 먼지처럼 작은 먼지처럼\n날리는 눈이 나라면\n조금 더 빨리\n네게 닿을 수 있을 텐데\n눈꽃이 떨어져요\n또 조금씩 멀어져요\n보고 싶다 보고 싶다\n보고 싶다 보고 싶다\n얼마나 기다려야\n또 몇 밤을 더 새워야\n널 보게 될까 널 보게 될까\n만나게 될까 만나게 될까\n추운 겨울 끝을 지나\n다시 봄날이 올 때까지\n꽃 피울 때까지\n그곳에 좀 더 머물러줘 \n머물러줘\n니가 변한 건지\n니가 변한 건지\n아니면 내가 변한 건지\n내가 변한 건지\n이 순간 흐르는 시간조차 미워\n우리가 변한 거지 뭐\n모두가 그런 거지 뭐\n그래 밉다 니가 넌 떠났지만\n단 하루도 너를\n잊은 적이 없었지 난\n솔직히 보고 싶은데\n이만 너를 지울게\n그게 널 원망하기보단\n덜 아프니까\n시린 널 불어내 본다\n연기처럼 하얀 연기처럼\n말로는 지운다 해도\n사실 난 아직 널 보내지 못하는데\n눈꽃이 떨어져요\n또 조금씩 멀어져요\n보고 싶다 보고 싶다\n보고 싶다 보고 싶다\n얼마나 기다려야\n또 몇 밤을 더 새워야\n널 보게 될까 널 보게 될까\n만나게 될까 만나게 될까\nYou know it all\nYou\'re my best friend\n아침은 다시 올 거야\n어떤 어둠도 어떤 계절도\n영원할 순 없으니까\n벚꽃이 피나봐요\n이 겨울도 끝이 나요\n보고 싶다 보고 싶다 \n보고 싶다 보고 싶다\n조금만 기다리면\n며칠 밤만 더 새우면\n만나러 갈게 만나러 갈게\n데리러 갈게 데리러 갈게\n추운 겨울 끝을 지나\n다시 봄날이 올 때까지\n꽃 피울 때까지\n그곳에 좀 더 머물러줘 \n머물러줘"\n"No I don\'t wanna go too fast\nCuz nothing really lasts\nI think I need some time\nBut I can\'t get you off my mind\n일단 시작부터\n제일 센 걸로 부탁해 바텐더\n연속해 들이키고 나니\n모두 다 예뻐\n보여 침이 고여\nthese ladies so loyal\n그러다 널 처음 봤어\ngeez girl love me tender\n난 씩씩하게 말을 걸어\n넌 저기 시시한 여자와는 달리\n틱틱 거려 칙칙하던\n분위기에 한 줄기 빛\n설렘 정도가 지나쳐\n마치 사춘기\n훔치는 너의 눈빛에\n입술은 바짝 마르지\n오랜만에 느껴보는 이런 떨림\n이러지도 저러지도 못해 나\n이 밤이 다 가기 전에\n난 널 내 품 안에 원해\nReal love\nI think I wanna just\n고민고민 하지마 Hey\n에라 모르겠다 I Love ya\n에라 모르겠다 I Love ya\n에라 모르겠다 I Love ya\nGirl I wanna get down\n에라 모르겠다 \n에라 모르겠다\n에라 모르겠다 \nGirl I wanna get down\n설렘을 찾고 싶어 마르고 닳도록\n난 여러 명의 포로 도망치네\n이곳 빠삐용\n나 지긋지긋 희끗희끗 흰머리가 나\n양아치 이제 끝 바람둥이 한 가닥\n나라는 남자를 모르던\n그런 네가 좋았지\n몰래 난 원래 모든 Girl\n싫증 잘 느끼는 벌레\n나이를 먹어도 사랑은\n단 1도 모르겠어\n뒤처리를 못해\n피눈물 없는 로맨스\n장단 없는 game\n너는 오락가락하고\n멜로디가 다른 알토와 소프라노\n어차피 우리는 끊어질 거야\n딱 잘라 말할게\n타락해버린 꿈에 Eldorado\n훔치는 너의 눈빛에\n입술은 바짝 마르지\n오랜만에 느껴보는 이런 떨림\n이러지도 저러지도 못해 나\n이 밤이 다 가기 전에\n난 널 내 품 안에 원해\nReal love\nI think I wanna just\n고민고민 하지마 Hey\n에라 모르겠다 I Love ya\n에라 모르겠다 I Love ya\n에라 모르겠다 I Love ya\nGirl I wanna get down\n에라 모르겠다\n에라 모르겠다\n에라 모르겠다\nGirl I wanna get down\nYou & me 같이 차를 타고 ride\n술 취했으니 눈 좀 붙여 잠깐만\n어디 가서 쉴까 baby\n난 손만 잡고 자\n속은 뻔해 honey honey\nbut I want it and you know it\n에라 모르겠다 I Love ya\n에라 모르겠다 I Love ya\n에라 모르겠다 에라 모르겠다\n에라 모르겠다\n에라 모르겠다\n에라 모르겠다\nGirl I wanna get down\nGirl I wanna get down\nGirl I wanna get down\n에라 모르겠다 I Love ya\n에라 모르겠다 I Love ya\n에라 모르겠다 I Love ya\nGirl I wanna get down\n에라 모르겠다\n에라 모르겠다\n에라 모르겠다\nGirl I wanna get down"\n"착해 빠진 게 독한 소리 할 때\n분명 지 속도 속 아니었겠죠\n잡는 목소리 머뭇거리지도 않고\n날 떠날 땐 분명 이 악물었겠죠\n상처받지 않은 듯 돌아섰지만\n애같이 눈물을 사탕처럼 \n막 흘리면서 가\n다 흘리면서 가 \n자기보다 큰 슬픔을 \n쇠똥구리처럼 힘겹게 \n굴리면서 가\n난 왜 그런 널 안지 못했을까\n그날 결판 짓던 순간에 \n터널 같던 너의 눈가\n그 생각만 하면 자꾸 내 맘이 짠해\n저기요 좀 찾아주세요 \n그 사람 나 아니면 갈 곳이 없어요\n마른 두 다리로 어딘가 헤맬 텐데\n내가 집이 돼주기로 했는데\n그리워서 그리워서\n밤하늘 바라봐요\n그대 알아 \n나도 그대 마음과 같아\n시간 지나 사랑이면\n그래도 사랑이면\nLonely you \n돌아와 너의 집으로\n서로의 심술 맞은 자존심 \n딱 그 정도 거리만큼 \n우린 떨어져 걸었어\n뾰족한 맘 \n괜히 툭 뱉은 말들에 비해 \n진심은 항상 한 박자 느렸어\n그 한 발짝 물러서기가 \n그렇게 힘들어 \n이 꼴 저 꼴 다 본 끝에 \n여기까지네\n30평 아파트가 돼주고 \n싶었는데 \n겨우 원룸밖에 못 돼 줘서 \n미안해\n처음엔 시원했어 너 떠나간 후\n싹 지워냈어 그런 줄 알았어\n근데 아니더라고 나도 모르게 \n익숙한 뒷모습을 몰래 \n따라가더라\n넌 줄 알았어\n친구들은 다 나쁜 년이라고 \n술자리서 욕하는데\n속으론 지들이 뭘 안다고\n니 편들게 되더라 \n머리가 아프네 \n집 가야지 지갑 어디다 뒀더라\n그리워서 그리워서\n밤하늘 바라봐요\n그대 알아 \n나도 그대 마음과 같아\n시간 지나 사랑이면\n그래도 사랑이면\nLonely you \n돌아와 너의 집으로\n아저씨 사실 나 갈 곳 없어요\n그 사람 아니면 \n내 마음 둘 곳 없어요\n어딜 가야 다시 볼 수 있을까요\n우리 집을 못 찾겠군요\n아저씨 그 사람 찾아주세요\n그 사람 나 아님 잠들 곳 없어요\n어딜 가야 다시 볼 수 있을까요\n우리 집을 못 찾겠군요\n그리워서 그리워서\n밤하늘 바라봐요\n그대 알아 \n나도 그대 마음과 같아\n시간 지나 사랑이면\n그래도 사랑이면\nLonely you \n돌아와 너의 집으로\n저 골목길 돌면 자주 걷던 길과\n너가 마중 나왔던 버스 정류장\n미용실을 지나\n오르막길 올라서\n가다 보면 어느새 \n불 꺼진 너의 집 앞\n난 믿어\n그리워하다\n언젠가 우연처럼 만나게 될 \n만화 같은 기적 \n그 사람 지금 어디 있을까요\n우리 집을 못 찾겠군요\n돌아봐도 사랑이면\n그래도 사랑이면\n그땐 울고 있는 \n나를 찾아줄래"\n"일이 피곤했나\n오늘따라 한 두 잔에 퍼지네\n반 뼘짜리 위로\n한숨 피우고 나니\n기분이 좀 나아지네\n요즘 들어 사는 게\n봄 가을 같아 좋은 건\n다 짧게 지나가\n어떤 이는 내가 아닌\n나로 나를 만들어\n들었다 놓곤\n스치듯 내 곁을 떠나가\n내가 강해졌던 건지\n무뎌졌던 건지\n일년에 한 두 번\n울먹임을 다했던 내가\n눈물이 다 나네\n가리워진 길\n그 노래가\n내 마음 ...

# %%
## 형태소를 분석하는 OKt Class 생성
okt = Okt()

# %%
## Okt를 이용해서 문자열의 형태를 분석
nouns= okt.nouns(text)

# %%
# 글자수가 2개 이상인 문자만 필터
words= [n for n in nouns if len(n) >1 ]

# %%
words
# Out:
# ['보고',
#  '보고',
#  '너희',
#  '사진',
#  '보고',
#  '보고',
#  '시간',
#  '우리',
#  '얼굴',
#  '한번',
#  '조차',
#  '우리',
#  '온통',
#  '겨울',
#  '겨울',
#  '마음',
#  '시간',
#  '홀로',
#  '설국열차',
#  '잡고',
#  '지구',
#  '반대편',
#  '겨울',
#  '끝내',
#  '그리움',
#  '얼마나',
#  '봄날',
#  '허공',
#  '먼지',
#  '먼지',
#  '나라',
#  '조금',
#  '눈꽃',
#  '보고',
#  '보고',
#  '보고',
#  '보고',
#  '얼마나',
#  '겨울',
#  '지나',
#  '다시',
#  '봄날',
#  '순간',
#  '시간',
#  '우리',
#  '거지',
#  '모두',
#  '거지',
#  '하루',
#  '보고',
#  '그게',
#  '연기',
#  '연기',
#  '해도',
#  '사실',
#  '눈꽃',
#  '보고',
#  '보고',
#  '보고',
#  '보고',
#  '얼마나',
#  '아침',
#  '다시',
#  '어둠',
#  '계절',
#  '벚꽃',
#  '피나',
#  '겨울',
#  '보고',
#  '보고',
#  '보고',
#  '보고',
#  '조금',
#  '며칠',
#  '겨울',
#  '지나',
#  '다시',
#  '봄날',
#  '일단',
#  '시작',
#  '제일',
#  '부탁',
#  '바텐더',
#  '연속',
#  '나니',
#  '모두',
#  '고여',
#  '처음',
#  '저기',
#  '여자',
#  '달리',
#  '틱틱',
#  '거려',
#  '분위기',
#  '줄기',
#  '정도',
#  '마치',
#  '사춘기',
#  '눈빛',
#  '입술',
#  '바짝',
#  '마르지',
#  '가기',
#  '고민',
#  '고민',
#  '마르고',
#  '여러',
#  '명의',
#  '포로',
#  '빠삐용',
#  '지긋지긋',
#  '희끗희끗',
#  '머리',
#  '아치',
#  '이제',
#  '바람둥이',
#  '가닥',
#  '나라',
#  '남자',
#  '몰래',
#  '원래',
#  '모든',
#  '싫증',
#  '벌레',
#  '나이',
#  '사랑',
#  '처리',
#  '눈물',
#  '로맨스',
#  '장단',
#  '오락가락',
#  '멜로디',
#  '다른',
#  '알토',
#  '소프라노',
#  '어차피',
#  '우리',
#  '눈빛',
#  '입술',
#  '바짝',
#  '마르지',
#  '가기',
#  '고민',
#  '고민',
#  '타고',
#  '취했으',
#  '잠깐',
#  '어디',
#  '잡고',
#  '소리',
#  '분명',
#  '속도',
#  '목소리',
#  '분명',
#  '상처',
#  '눈물',
#  '사탕',
#  '자기',
#  '슬픔',
#  '쇠똥구리',
#  '면서',
#  '안지',
#  '그날',
#  '결판',
#  '순간',
#  '터널',
#  '눈가',
#  '생각',
#  '자꾸',
#  '저기',
#  '사람',
#  '다리',
#  '어딘가',
#  '밤하늘',
#  '그대',
#  '그대',
#  '마음',
#  '시간',
#  '지나',
#  '사랑',
#  '이면',
#  '사랑',
#  '이면',
#  '서로',
#  '심술',
#  '자존심',
#  '정도',
#  '거리',
#  '우린',
#  '진심',
#  '항상',
#  '박자',
#  '발짝',
#  '지네',
#  '아파트',
#  '겨우',
#  '원룸',
#  '처음',
#  '뒷모습',
#  '몰래',
#  '친구',
#  '술자리',
#  '머리',
#  '가야',
#  '지갑',
#  '어디',
#  '밤하늘',
#  '그대',
#  '그대',
#  '마음',
#  '시간',
#  '지나',
#  '사랑',
#  '이면',
#  '사랑',
#  '이면',
#  '아저씨',
#  '사실',
#  '사람',
#  '마음',
#  '가야',
#  '다시',
#  '우리',
#  '아저씨',
#  '사람',
#  '사람',
#  '가야',
#  '다시',
#  '우리',
#  '밤하늘',
#  '그대',
#  '그대',
#  '마음',
#  '시간',
#  '지나',
#  '사랑',
#  '이면',
#  '사랑',
#  '이면',
#  '골목길',
#  '자주',
#  '마중',
#  '버스',
#  '정류장',
#  '미용실',
#  '지나',
#  '오르막',
#  '우연',
#  '만화',
#  '기적',
#  '사람',
#  '지금',
#  '어디',
#  '우리',
#  '사랑',
#  '이면',
#  '사랑',
#  '이면',
#  '그땐',
#  '오늘',
#  '위로',
#  '한숨',
#  '나니',
#  '기분',
#  '요즘',
#  '가을',
#  '나로',
#  '무뎌졌던',
#  '눈물',
#  '노래',
#  '마음',
#  '조금',
#  '이유',
#  '스트레스',
#  '버티고',
#  '증발',
#  '대가',
#  '그냥',
#  '어도',
#  '슬픔',
#  '눈물',
#  '엄지',
#  '거지',
#  '라며',
#  '주병',
#  '마흔',
#  '담배',
#  '구름',
#  '우릴',
#  '기침',
#  '웃음',
#  '잠시',
#  '혼자',
#  '우린',
#  '서로',
#  '친구',
#  '때론',
#  '우울',
#  '불운',
#  '나태',
#  '그물',
#  '자기',
#  '물음',
#  '머릿속',
#  '계속',
#  '현실',
#  '때론',
#  '유령',
#  '고독',
#  '무덤',
#  '노래',
#  '후렴',
#  '그냥',
#  '어도',
#  '슬픔',
#  '눈물',
#  '엄지',
#  '혼자',
#  '오늘',
#  '누군가',
#  '혼자',
#  '역시',
#  '외로워',
#  '평점',
#  '채점',
#  '몇몇',
#  '하루',
#  '문턱',
#  '나로',
#  '가끔',
#  '사나',
#  '도대체',
#  '어디',
#  '가나',
#  '가면',
#  '이제',
#  '가명',
#  '갈피',
#  '잡고',
#  '누군가',
#  '계산',
#  '가치',
#  '거짓',
#  '껍질',
#  '세상',
#  '우린',
#  '서로',
#  '장난',
#  '판단',
#  '잠깐',
#  '얼마나',
#  '바람',
#  '그냥',
#  '어도',
#  '슬픔',
#  '눈물',
#  '엄지',
#  '하나',
#  '추억',
#  '하나',
#  '사랑',
#  '하나',
#  '하나',
#  '동경',
#  '하나',
#  '하나',
#  '어머니',
#  '당신',
#  '하늘',
#  '우러러',
#  '부끄러움',
#  '당신',
#  '모든',
#  '사랑',
#  '때론',
#  '무기',
#  '당신',
#  '첩방',
#  '등불',
#  '기억',
#  '용기',
#  '내지',
#  '대신',
#  '연필',
#  '창살',
#  '건너편',
#  '하늘',
#  '이름',
#  '나라',
#  '오늘',
#  '하나',
#  '추억',
#  '하나',
#  '사랑',
#  '하나',
#  '하나',
#  '동경',
#  '하나',
#  '하나',
#  '어머니',
#  '바람',
#  '기억',
#  '하늘',
#  '헤던',
#  '당신',
#  '당신',
#  '하늘',
#  '우러러',
#  '부끄러움',
#  '당신',
#  '모든',
#  '사랑',
#  '비판',
#  '비아',
#  '입가',
#  '시대',
#  '고개',
#  '한국인',
#  '한국',
#  '사람',
#  '촛불',
#  '바람',
#  '이름',
#  '나라',
#  '설움',
#  '죄책감',
#  '철인',
#  '자화상',
#  '위로',
#  '겨우',
#  '겨우',
#  '걸음',
#  '오늘',
#  '당신',
#  '시가',
#  '광장',
#  '하나',
#  '추억',
#  '하나',
#  '사랑',
#  '하나',
#  '하나',
#  '동경',
#  '하나',
#  '하나',
#  '어머니',
#  '바람',
#  '기억',
#  '하늘',
#  '헤던',
#  '당신',
#  '하나',
#  '가슴속',
#  '하나',
#  '하나',
#  '위로',
#  '만주',
#  '일본',
#  '누구',
#  '이기',
#  '나라',
#  '이름',
#  '지금',
#  '그대',
#  '명예',
#  '나라',
#  '시인',
#  '하나',
#  '추억',
#  '하나',
#  '사랑',
#  '하나',
#  '하나',
#  '동경',
#  '하나',
#  '하나',
#  '어머니',
#  '바람',
#  '기억',
#  '하늘',
#  '헤던',
#  '헤던',
#  '당신',
#  '접기',
#  '프린트',
#  '가사',
#  '오류',
#  '신고',
#  '작사',
#  '작곡',
#  '혹시',
#  '별도',
#  '보고',
#  '보고',
#  '별도',
#  '보고',
#  '지금',
#  '피해',
#  '오늘',
#  '내겐',
#  '두운',
#  '지나',
#  '아침',
#  '온대',
#  '구름',
#  '보이지',
#  '자리',
#  '보이지',
#  '항상',
#  '구름',
#  '이제',
#  '리기',
#  '기도',
#  '혹시',
#  '별도',
#  '보고',
#  '보고',
#  '별도',
#  '보고',
#  '지금',
#  '피해',
#  '노래',
#  '보고',
#  '지금',
#  '매일',
#  '피해',
#  '기도',
#  '시간',
#  '과정',
#  '혹시',
#  '별도',
#  '보고',
#  '보고',
#  '별도',
#  '보고',
#  '지금',
#  '피해',
#  '그대',
#  '순간',
#  '보고',
#  '이후',
#  '흔적',
#  '누구',
#  '항상',
#  '수도',
#  '수도',
#  '혹시',
#  '별도',
#  '보고',
#  '보고',
#  '별도',
#  '보고',
#  '지금',
#  '피해',
#  '살때',
#  '피아노',
#  '영재',
#  '베토벤',
#  '모짜르트',
#  '바흐',
#  '쇼팽',
#  '선배',
#  '가사',
#  '새끼',
#  '모두',
#  '엿먹어',
#  '베르사체',
#  '무한리필',
#  '그게',
#  '악장',
#  '하얀색',
#  '대리석',
#  '그게',
#  '악장',
#  '바로',
#  '지휘봉',
#  '사실',
#  '수트',
#  '바지',
#  '그냥',
#  '부자',
#  '거의',
#  '젠틀',
#  '건희',
#  '칭호',
#  '노창',
#  '방금',
#  '라인',
#  '리스크',
#  '첨벙',
#  '비닐',
#  '피아노',
#  '살기',
#  '위해',
#  '숨구멍',
#  '악보',
#  '따윈',
#  '동네',
#  '구덩이',
#  '선언',
#  '자신',
#  '임임',
#  '박아',
#  '소나타',
#  '오직',
#  '그것',
#  '따윈',
#  '생각',
#  '안해',
#  '지금',
#  '악장',
#  '카포',
#  '절대로',
#  '박수',
#  '악장',
#  '할렐루야',
#  '살때',
#  '피아노',
#  '영재',
#  '베토벤',
#  '모짜르트',
#  '바흐',
#  '쇼팽',
#  '선배',
#  '가사',
#  '새끼',
#  '모두',
#  '엿먹어',
#  '베르사체',
#  '무한리필',
#  '그게',
#  '악장',
#  '하얀색',
#  '대리석',
#  '그게',
#  '악장',
#  '바로',
#  '지휘봉',
#  '영재',
#  '파우스트',
#  '괴테',
#  '고흐',
#  '이름',
#  '한국',
#  '아인슈타인',
#  '노멀',
#  '엿먹',
#  '여기',
#  '무덤',
#  '예술',
#  '전당',
#  '마에스트로',
#  '계급',
#  '백건우',
#  '카라얀',
#  '정도',
#  '클래식',
#  '용어',
#  '악장',
#  '이력',
#  '전용',
#  '보드',
#  '고장',
#  '맥북',
#  '내겐',
#  '위인',
#  '세종',
#  '연주',
#  '살때',
#  '피아노',
#  '영재',
#  '베토벤',
#  '모짜르트',
#  '바흐',
#  '쇼팽',
#  '선배',
#  '가사',
#  '새끼',
#  '모두',
#  '엿먹어',
#  '베르사체',
#  '무한리필',
#  '그게',
#  '악장',
#  '하얀색',
#  '대리석',
#  '그게',
#  '악장',
#  '바로',
#  '지휘봉',
#  '눈물',
#  '마지막',
#  '눈물',
#  '눈물',
#  '눈물',
#  '마음',
#  '영혼',
#  '이건',
#  '주문',
#  '날개',
#  '악마',
#  '어서',
#  '이상',
#  '수도',
#  '취해',
#  '이제',
#  '위스키',
#  '눈물',
#  '마지막',
#  '눈물',
#  '정신',
#  '비밀',
#  '감옥',
#  '중독',
#  '깊이',
#  '다른',
#  '사람',
#  '성배',
#  '눈물',
#  '마지막',
#  '눈물',
#  '손길',
#  '어차피',
#  '거부',
#  '눈물',
#  '눈물',
#  '소릴',
#  '내일',
#  '알람',
#  '그리움',
#  '다시',
#  '안고',
#  '잡고',
#  '보고',
#  '후회',
#  '혹시',
#  '그냥',
#  '보지',
#  '사람과',
#  '이건',
#  '노래',
#  '절대로',
#  '오해',
#  '다시',
#  '위해',
#  '노래',
#  '그녀',
#  '웃기',
#  '지금',
#  '가사',
#  '거리',
#  '노래',
#  '만큼',
#  '우리',
#  '사랑',
#  '이별',
#  '소리',
#  '이해',
#  '그게',
#  '당장',
#  '노래',
#  '아무',
#  '보지',
#  '사람과',
#  '만약',
#  '전화',
#  '잠깐',
#  '그냥',
#  '생각',
#  '기적',
#  '말투',
#  '행동',
#  '친굴',
#  '만날',
#  '항상',
#  '눈치',
#  '자격',
#  '자신',
#  '여자',
#  '방법',
#  '이해',
#  '사람과',
#  '오늘',
#  '우리',
#  '그것',
#  '오늘',
#  '절대',
#  '죽지',
#  '어둠',
#  '세상',
#  '기어',
#  '어서',
#  '겨눠',
#  '조준',
#  '발사',
#  '뱁새',
#  '친구',
#  '조준',
#  '발사',
#  '죽지',
#  '소리',
#  '조준',
#  '발사',
#  '성공',
#  '차트',
#  '덤블링',
#  '트램펄린',
#  '누가',
#  '우린',
#  '수가',
#  '실패',
#  '서로',
#  '전부',
#  '오늘',
#  '절대',
#  '방탄',
#  '겨눠',
#  '조준',
#  '발사',
#  '뱁새',
#  '친구',
#  '조준',
#  '발사',
#  '죽지',
#  '소리',
#  '조준',
#  '발사',
#  '두려움',
#  '따위',
#  '유리천장',
#  '따윈',
#  '부숴',
#  '승리',
#  '그날',
#  '무릎',
#  '뱁새',
#  '친구',
#  '조준',
#  '발사',
#  '죽지',
#  '소리',
#  '조준',
#  '발사',
#  '손목',
#  '길거릴',
#  '도배',
#  '우리',
#  '노랜',
#  '놀이',
#  '보기',
#  '이건',
#  '범죄',
#  '대신',
#  '마이크',
#  '불과',
#  '장악',
#  '뭉치',
#  '닥치고',
#  '콘텐츠',
#  '역시',
#  '과시',
#  '부담',
#  '소재',
#  '인터넷',
#  '접속',
#  '오브',
#  '역할',
#  '메인',
#  '자리',
#  '세대',
#  '대세',
#  '장래희망',
#  '얼간이',
#  '하루',
#  '동선',
#  '무대',
#  '작업실',
#  '오천만',
#  '하쿠나마타타',
#  '날개',
#  '누울',
#  '제대로',
#  '보고',
#  '소파',
#  '머리',
#  '공기',
#  '우린',
#  '황인종',
#  '먹듯',
#  '실검',
#  '실력',
#  '예의',
#  '시비',
#  '목적',
#  '성공',
#  '첫째',
#  '악의',
#  '단지',
#  '티켓',
#  '매진',
#  '바로',
#  '차기작',
#  '매진',
#  '장관',
#  '바닥',
#  '높이',
#  '과로',
#  '체질',
#  '링거',
#  '투혼',
#  '휴가',
#  '반납',
#  '뇌물',
#  '위법',
#  '그림',
#  '일부',
#  '일거수일투족',
#  '세간',
#  '집중',
#  '논란',
#  '재기',
#  '탄력',
#  '절대',
#  '절제',
#  '누울',
#  '제대로',
#  '보고',
#  '소파',
#  '머리',
#  '공기',
#  '증명',
#  '안중',
#  '에이',
#  '에이',
#  '재수',
#  '삼각관계',
#  '사실',
#  '바다',
#  '직직직',
#  '의식',
#  '머리',
#  '손목',
#  '길거릴',
#  '도배',
#  '우리',
#  '노랜',
#  '놀이',
#  '보기',
#  '이건',
#  '범죄',
#  '수가',
#  '눈빛',
#  '오직',
#  '모든',
#  '남자',
#  '매일',
#  '대부분',
#  '착각',
#  '절대',
#  '심장',
#  '아주',
#  '때론',
#  '귓가',
#  '휘파람',
#  '수가',
#  '마음',
#  '심장',
#  '점점',
#  '가까이',
#  '휘파람',
#  '파라파라',
#  '파라',
#  '휘파람',
#  '파라파라',
#  '파라',
#  '아무',
#  '소리',
#  '지금',
#  '생각',
#  '느낌',
#  '갈수록',
#  '마음속',
#  '게임',
#  '택해',
#  '누가',
#  '가로',
#  '가기',
#  '수가',
#  '마음',
#  '심장',
#  '점점',
#  '가까이',
#  '휘파람',
#  '파라파라',
#  '파라',
#  '휘파람',
#  '파라파라',
#  '파라',
#  '바람',
#  '인연',
#  ...]

# %%
# 글자들의 빈도수를 출력
cnt= Counter(words)

# %%
wc=WordCloud(
    font_path='malgun',
    width=400,
    height=400,
    scale=2.0,
    max_font_size=250,
    max_words=100
)
gen=wc.generate_from_frequencies(cnt)
plt.figure()
plt.axis('off')
plt.imshow(gen)

# %%
import sys

# %%
sys.path
# Out:
# ['c:\\깃허브\\test\\python\\240328',
#  'c:\\파이썬이다\\python312.zip',
#  'c:\\파이썬이다\\DLLs',
#  'c:\\파이썬이다\\Lib',
#  'c:\\파이썬이다',
#  '',
#  'C:\\Users\\qhwjd\\AppData\\Roaming\\Python\\Python312\\site-packages',
#  'C:\\Users\\qhwjd\\AppData\\Roaming\\Python\\Python312\\site-packages\\win32',
#  'C:\\Users\\qhwjd\\AppData\\Roaming\\Python\\Python312\\site-packages\\win32\\lib',
#  'C:\\Users\\qhwjd\\AppData\\Roaming\\Python\\Python312\\site-packages\\Pythonwin',
#  'c:\\파이썬이다\\Lib\\site-packages']
