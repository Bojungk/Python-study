# %%
# !pip install seaborn
# Out:
# Collecting seaborn
#   Obtaining dependency information for seaborn from https://files.pythonhosted.org/packages/83/11/00d3c3dfc25ad54e731d91449895a79e4bf2384dc3ac01809010ba88f6d5/seaborn-0.13.2-py3-none-any.whl.metadata
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\파이썬이다\lib\site-packages (from seaborn) (1.26.4)
# Requirement already satisfied: pandas>=1.2 in c:\파이썬이다\lib\site-packages (from seaborn) (2.2.1)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\파이썬이다\lib\site-packages (from seaborn) (3.8.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\파이썬이다\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\파이썬이다\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\파이썬이다\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.50.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\파이썬이다\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\qhwjd\appdata\roaming\python\python312\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.0)
# Requirement already satisfied: pillow>=8 in c:\파이썬이다\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\파이썬이다\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\qhwjd\appdata\roaming\python\python312\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\파이썬이다\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\파이썬이다\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\qhwjd\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
#    ---------------------------------------- 0.0/294.9 kB ? eta -:--:--
#    ---------------------------------------- 0.0/294.9 kB ? eta -:--:--
#    ----------- ---------------------------- 81.9/294.9 kB 2.2 MB/s eta 0:00:01
#    ---------------------------------------- 294.9/294.9 kB 4.5 MB/s eta 0:00:00
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# 라이브러리 로드
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
## matplotlib을 이용한 그래프의 시각화
#라인 그래프 (플롯 그래프)
# y축의 데이터만 존재하는 경우
# x축의 데이터는 0부터 시작해서 1씩 증가하는 형태로 생성
y_list= [10, 5, 8, 16]
plt.plot(y_list)
# show(): print() 같은 기능
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#x, y축의 데이터가 모두 존재하는 경우
x_list=[1, 3, 6, 10]
y_list=[1,2,3,4]
plt.plot(x_list, y_list)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.plot(x_list, y_list, 'green')
plt.show()

# %%
#라인 그래프의 라인의 색상과 종류를 변경
plt.plot(x_list, y_list, '#FF0077')
plt.show()

# %%
plt.plot([1,2,3,4], [10,20,10,30], label='A')
plt.plot([1,3,5,7],[20,40,8,1], label='B')
# plt.show()
# x축에 라벨링
plt.xlabel('X')
# y축 라벨링
plt.ylabel('Y')
#그래프의 이름 표시
plt.title('그래프')
# 범례 추가
plt.legend()
plt.show()

# %%
## 그래프를 출력할때 한글이 깨진다.
## matplotlib에서 사용하는 폰트를 변경하는 코드는 실행
# windows와 MAC은 사용하는 폰트가 다르다.

# %%
import platform

# %%
platform.system()
# Out:
# 'Windows'

# %%
if platform.system() =='Darwin':
    plt.rc('font', family = 'AppleGothic')
else:
    plt.rc('font', family= 'Malgun Gothic')

# %%
# 막대 그래프
x=[1,2,3,4]
y=[80,70,90,75]

plt.bar(x,y)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# 특정 막대의 색상을 변경

plt.barh(x, y)
plt.show()

# %%
#옵션 추가 (색상, 너비 변경)
plt.bar(x, y, width=0.2, color= 'r', 'b', 'g', 'y')
plt.show()
# Out:
#   Cell In[41], line 2
#     plt.bar(x, y, width=0.2, color= 'r', 'b',)
#                                              ^
# SyntaxError: positional argument follows keyword argument

# %%
#특정 막대의 색상을 변경 
graph = plt.bar(x, y)
graph[2].set_color('r')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#산점도 그래프
x=np.random.random(30)
y=np.random.random(30)

# %%
plt.scatter(x, y)
plt.show()

# %%
df= pd.read_csv("../csv/drinks.csv")

# %%
df.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0        AS
# 1                           4.9        EU
# 2                           0.7        AF
# 3                          12.4        EU
# 4                           5.9        AF

# %%
# 맥주소비량, 위스키소비량, 와인의 소비량, 알콜도수의
#상관 관계 확인
# 상관 계수: -1~1
    #-1: 하나의 데이터가 오르면 나머지 하나의 데이터는 내려감
    #1: 하나의 데이터가 오르면 나머지 하나의 데이터도 같이 오름
    #0: 두 개의 데이터가 무작위
#DataFrame안에 있는 corr() 함수 호출 
corr=df[['beer_servings', 'spirit_servings','wine_servings',
    'total_litres_of_pure_alcohol']].corr('pearson')

# %%
# seaborn 라이브러리를 이용하여 히트맵 시각화
cols=['beer', 'spirit', 'wine', 'alcohol']

hm= sns.heatmap(
    corr.values,
    cbar = True,    #사이드바 표시
    annot= True,    #히트맵에 숫자를 표시
    square=True,    #정사각형 표시
    fmt='0.3f', #숫자의 소수점 자리수
    annot_kws={'size':20}, # 숫자의 크기
    xticklabels=cols,
    yticklabels=cols
)

# %%
sns.pairplot(
    df.loc[:, 'beer_servings' : 'total_litres_of_pure_alcohol'],
    height= 2.5,
    kind='reg'
)
plt.show()

# %%
pivot_data.plot(kind='bar')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[63], line 1
# ----> 1 pivot_data.plot(kind='bar')
#
# NameError: name 'pivot_data' is not defined

# %%
group_data.plot(kind='bar')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[67], line 1
# ----> 1 group_data.plot(kind='bar')
#
# NameError: name 'group_data' is not defined
