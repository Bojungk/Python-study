# %%
# !conda install -c conda-forge folium

# %%
import folium

#서울 지도 만들기
seoul_map=folium.Map(location=[37.55,126.98], zoom_start=12)

#지도를 HTML 파일로 저장하기
seoul_map.save('./seoul.html')

# %%
seoul_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8079630f61854d2bdff29556d3c1bdba {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8079630f61854d2bdff29556d3c1bdba&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8079630f61854d2bdff29556d3c1bdba = L.map(
#                 &quot;map_8079630f61854d2bdff29556d3c1bdba&quot;,
#                 {
#                     center: [37.55, 126.98],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6809b2baa65cce0769bbe5f2e47ccf8f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_6809b2baa65cce0769bbe5f2e47ccf8f.addTo(map_8079630f61854d2bdff29556d3c1bdba);
#
#
#             tile_layer_6809b2baa65cce0769bbe5f2e47ccf8f.addTo(map_8079630f61854d2bdff29556d3c1bdba);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
from folium.map import Popup
import pandas as pd
import folium

df=pd.read_excel('./서울지역 대학교 위치.xlsx')

seoul_map=folium.Map(location=[37.55,126.98], zoom_start=12)

# %%
seoul_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2a2514612a25af1124cbc1eb189087a8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2a2514612a25af1124cbc1eb189087a8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2a2514612a25af1124cbc1eb189087a8 = L.map(
#                 &quot;map_2a2514612a25af1124cbc1eb189087a8&quot;,
#                 {
#                     center: [37.55, 126.98],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6d0ca4f7e7a45250b11747174049fc6e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_6d0ca4f7e7a45250b11747174049fc6e.addTo(map_2a2514612a25af1124cbc1eb189087a8);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
df.head()
# Out:
#             대학교         위도          경도
# 0  KAIST 서울캠퍼스   37.592573  127.046737
# 1         KC대학교  37.548345  126.854797
# 2  가톨릭대학교(성신교정)  37.585922  127.004328
# 3  가톨릭대학교(성의교정)  37.499623  127.006065
# 4      감리교신학대학교  37.567645  126.961610

# %%
# 대학교 위정보를 Marker로 표시
for name, lat, lng in zip(df.대학교, df.위도, df.경도):
    folium.Marker([lat, lng], popup=name).add_to(seoul_map)

# %% [markdown]
# ## Iframe popup

# %%
from folium.map import Popup
import pandas as pd
import folium

df=pd.read_excel('./서울지역 대학교 위치.xlsx')

seoul_map=folium.Map(location=[37.55,126.98], zoom_start=12)

# %%
for name, lat, lng in zip(df.대학교, df.위도, df.경도):
    iframe = folium.IFrame(name, width=300, height=50)
    popup = folium.Popup(iframe, max_width = 300)
    folium.Marker([lat, lng], popup=popup).add_to(seoul_map)
   
seoul_map.save('./seoul_colleges.html')
seoul_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_489930d9dc200b4873af47d44c656abd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_489930d9dc200b4873af47d44c656abd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_489930d9dc200b4873af47d44c656abd = L.map(
#                 &quot;map_489930d9dc200b4873af47d44c656abd&quot;,
#                 {
#                     center: [37.55, 126.98],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8929ecc5c4988d6105b31daf7ac4d175 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_8929ecc5c4988d6105b31daf7ac4d175.addTo(map_489930d9dc200b4873af47d44c656abd);
#
#
#             var marker_17a860c75dbf9c3ef569b4617943b9b8 = L.marker(
#                 [37.592573, 127.046737],
#                 {}
#             ).addTo(map_489930d9dc200b4873af47d44c656abd);
#
#
#         var popup_e8e0f96f1696e6cf5202f65177fb7c5e = L.popup({&quot;maxWidth&quot;: 300});
#
#
#
#                 var i_frame_c89853ae279e6dd48cc56b6871e4e58a = $(`&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,CiAgICBLQUlTVCDshJzsmrjsuqDtjbzsiqQg&quot; width=&quot;300&quot; style=&quot;border:none !important;&quot; height=&quot;80&quot;&gt;&lt;/iframe&gt;`)[0];
#                 popup_e8e0f96f1696e6cf5202f65177fb7c5e.setContent(i_frame_c89853ae279e6dd48cc56b6871e4e58a);
#
#
#
#         marker_17a860c75dbf9c3ef569b4617943b9b8.bindPopup(popup_e8e0f96f1696e6cf5202f65177fb7c5e)
#         ;
#
#
#
#
#             var marker_c1fda251c0cb614c053a6a0903e7af58 = L.marker(
#                 [37.5483449, 126.8547974],
#                 {}
#             ).addTo(map_489930d9dc200b4873af47d44c656abd);
#
#
#         var popup_d78028564dab4953ffbb14134df45508 = L.popup({&quot;maxWidth&quot;: 300});
#
#
#
#                 var i_frame_7c92f5c495a3f0ddb0b253bc8581ab56 = $(`&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,CiAgICBLQ+uMgO2Vmeq1kA==&quot; width=&quot;300&quot; style=&quot;border:none !important;&quot; height=&quot;80&quot;&gt;&lt;/iframe&gt;`)[0];
#                 popup_d78028564dab4953ffbb14134df45508.setContent(i_frame_7c92f5c495a3f0ddb0b253bc8581ab56);
#
#
#
#         marker_c1fda251c0cb614c053a6a0903e7af58.bindPopup(popup_d78028564dab4953ffbb14134df45508)
#         ;
#
#
#
#
#             var marker_f6144d88f69767b680f8bc34ffce27ae = L.marker(
#                 [37.5859218, 127.0043275],
#                 {}
#             ).addTo(map_489930d9dc200b4873af47d44c656abd);
#
#
#         var popup_eb9d41bb84107c8e1c843cbc7996a670 = L.popup({&quot;maxWidth&quot;: 300});
#
#
#
#                 var i_frame_c189f944d9582b68eb6416cc1de7909f = $(`&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,CiAgICDqsIDthqjrpq3rjIDtlZnqtZAo7ISx7Iug6rWQ7KCVKQ==&quot; width=&quot;300&quot; style=&quot;border:none !important;&quot; height=&quot;80&quot;&gt;&lt;/iframe&gt;`)[0];
#                 popup_eb9d41bb84107c8e1c843cbc7996a670.setContent(i_frame_c189f944d9582b68eb6416cc1de7909f);
#
#
#
#         marker_f6144d88f69767b680f8bc34ffce27ae.bindPopup(popup_eb9d41bb84107c8e1c843cbc7996a670)
#         ;
#
#
#
#
#             var marker_b728c99e137e30ceaf314141c952523b = L.marker(
#                 [37.4996227, 127.0060653],
#                 {}
#             ).addTo(map_489930d9dc200b4873af47d44c656abd);
#
#
#         var popup_2f5d19e04d3e7d163453e65dfb2ed608 = L.popup({&quot;maxWidth&quot;: 300});
#
#
#
#                 var i_frame_06bf7b173e187961876eaf40b5c0555e = $(`&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,CiAgICDqsIDthqjrpq3rjIDtlZnqtZAo7ISx7J2Y6rWQ7KCVKQ==&quot; width=&quot;300&quot; style=&quot;border:none !important;&quot; height=&quot;80&quot;&gt;&lt;/iframe&gt;`)[0];
#                 popup_2f5d19e04d3e7d163453e65dfb2ed608.setContent(i_frame_06bf7b173e187961876eaf40b5c0555e);
#
#
#
#         marker_b728c99e137e30ceaf314141c952523b.bindPopup(popup_2f5d19e04d3e7d163453e65dfb2ed608)
#         ;
#
#
#
#
#             var marker_ba880852e9b9986d9ba8a54f1071d9db = L.marker(
#                 [37.5676455, 126.96161],
#                 {}
#             ).addTo(map_489930d9dc200b4873af47d44c656abd);
#
#
#         var popup_77cb5e9f7c08abb2576187f7dc97dcfc = L.popup({&quot;maxWidth&quot;: 300});
#
#
#
#                 var i_frame_197b5cb5e14d53f3a4c1180475b65631 = $(`&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,CiAgICDqsJDrpqzqtZDsi6DtlZnrjIDtlZnqtZA=&quot; width=&quot;300&quot; style=&quot;border:none !important;&quot; height=&quot;80&quot;&gt;&lt;/iframe&gt;`)[0];
#                 popup_77cb5e9f7c08abb2576187f7dc97dcfc.setContent(i_frame_197b5cb5e14d53f3a4c1180475b65631);

# %% [markdown]
# ### 원형 마커

# %%
from folium.map import Popup
import pandas as pd
import folium

df=pd.read_excel('./서울지역 대학교 위치.xlsx')

seoul_map=folium.Map(location=[37.55,126.98], zoom_start=12)

# %%
for name, lat, lng in zip(df.대학교, df.위도, df.경도):
    iframe = folium.IFrame(name, width=300, height=50)
    popup = folium.Popup(iframe, max_width = 300)
    folium.CircleMarker([lat, lng],
                        radius=10,                           #원의 반지름 
                        color='brown',                       #원의 둘레 색상
                        fill=True,
                        fill_color='coral',                  #원을 채우는 색
                        fill_opacity=0.7,                    #투명도
                        popup=popup).add_to(seoul_map)
       
seoul_map.save('./seoul_colleges.html')
seoul_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4e35c37c4a99daf22ae16be70bc84245 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4e35c37c4a99daf22ae16be70bc84245&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4e35c37c4a99daf22ae16be70bc84245 = L.map(
#                 &quot;map_4e35c37c4a99daf22ae16be70bc84245&quot;,
#                 {
#                     center: [37.55, 126.98],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2c1a749988a2ee159a8a0aec311ffdac = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_2c1a749988a2ee159a8a0aec311ffdac.addTo(map_4e35c37c4a99daf22ae16be70bc84245);
#
#
#             var circle_marker_08da06213c5f68f5f718819006b6ea4e = L.circleMarker(
#                 [37.592573, 127.046737],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;brown&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;coral&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_4e35c37c4a99daf22ae16be70bc84245);
#
#
#         var popup_53f8d7ffe216691de113148fc82e2989 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_efa3f6ff74bae25dea1a3fa54a37fd2c = $(`&lt;div id=&quot;html_efa3f6ff74bae25dea1a3fa54a37fd2c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;KAIST 서울캠퍼스 &lt;/div&gt;`)[0];
#                 popup_53f8d7ffe216691de113148fc82e2989.setContent(html_efa3f6ff74bae25dea1a3fa54a37fd2c);
#
#
#
#         circle_marker_08da06213c5f68f5f718819006b6ea4e.bindPopup(popup_53f8d7ffe216691de113148fc82e2989)
#         ;
#
#
#
#
#             var circle_marker_e5887794f507130619e9862208f882e3 = L.circleMarker(
#                 [37.5483449, 126.8547974],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;brown&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;coral&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_4e35c37c4a99daf22ae16be70bc84245);
#
#
#         var popup_52dcdf0c3984739da989b206f3ee52dc = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_69a018df466d7b2143b34e00a2b45f55 = $(`&lt;div id=&quot;html_69a018df466d7b2143b34e00a2b45f55&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;KC대학교&lt;/div&gt;`)[0];
#                 popup_52dcdf0c3984739da989b206f3ee52dc.setContent(html_69a018df466d7b2143b34e00a2b45f55);
#
#
#
#         circle_marker_e5887794f507130619e9862208f882e3.bindPopup(popup_52dcdf0c3984739da989b206f3ee52dc)
#         ;
#
#
#
#
#             var circle_marker_687649b33e7ebc4e2d4667021810d6d1 = L.circleMarker(
#                 [37.5859218, 127.0043275],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;brown&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;coral&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_4e35c37c4a99daf22ae16be70bc84245);
#
#
#         var popup_d285335847fd0cc514a8b0693228660e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_31aa05ba13f1808c2034a12cb8913a10 = $(`&lt;div id=&quot;html_31aa05ba13f1808c2034a12cb8913a10&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;가톨릭대학교(성신교정)&lt;/div&gt;`)[0];
#                 popup_d285335847fd0cc514a8b0693228660e.setContent(html_31aa05ba13f1808c2034a12cb8913a10);
#
#
#
#         circle_marker_687649b33e7ebc4e2d4667021810d6d1.bindPopup(popup_d285335847fd0cc514a8b0693228660e)
#         ;
#
#
#
#
#             var circle_marker_d54eba53b1f4a26d4962d972686dd3c1 = L.circleMarker(
#                 [37.4996227, 127.0060653],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;brown&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;coral&quot;, &quot;fillOpacity&quot;:
